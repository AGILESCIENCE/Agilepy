# %% [markdown]
# # Agilepy offaxis/ap comparison

# %% [markdown]
# ## Class init

# %%
from agilepy.api.AGEngVisibility2 import AGEngVisibility2

# %%
path = "/data01/homes/addis/Agilepy/agilepy/external_packages/offaxis_conf.yaml"
ageng = AGEngVisibility2(path)
# Out:
# 2020-10-20 16:27:45,076 [INFO    ] [AgilepyLogger] File and Console loggers are active. Log file: /data01/homes/addis/.conda/envs/agilepyenv/agiletools/agilepy/external_packages/offaxis/eng_data/logs/eng_api_tutorial_log.log

# %% [markdown]
# ## Offaxis tool

# %% [markdown]
# ### Data

# %%
time_windows = [[55599.0, 55600.0]]
ra = 263.85
dec = -32.93
fermi_path = "/data01/FERMI_DATA/SC00.fits"
#agile_path = "/data01/ASDC_PROC3/DATA_ASDCe/INDEX/LOG.log.index"
agile_path = "/data01/ASDC_PROC2/DATA_2/INDEX/LOG.log.index"
run = 49
zmax = 60
mode = "all"
step = 1

# %% [markdown]
# ### Run tool

# %%
dir = ageng.visibilityPlot2(time_windows, ra, dec, fermi_path, agile_path, run, zmax, mode, step)
# Out:
# new -----
#  55599.0 55600.0
# fermi time318729600.0 318816000.0
# Computing angular distance to the center of f.o.v
# This might take a while...
# Total integration time= 72668.61  s Total_bins: 0.0 2430 Mean sep. <  60 : 36.1274
# Total absolute time= 86400.00
# Total time spent at separation <  60  deg: 14287.11 s
# Relative time spent at separation < 60  deg: 19.66 %
# Relative time spent at separation > 60  deg: 80.34 %
# Absolute time spent at separation < 60  deg: 16.54  %
# Absolute time spent at separation > 60  deg: 67.57  %
# Duty Cycle:  84.11 %
# Plotting figure...
# Saving figure...
# Plotting histogram...
# Saving figure...
# agile 224121600.0 224208000.0
# 1328 1e+20 /AGILE_PROC3/DATA_ASDCSTDk/LOG/ag-224078334_STD1Kal.LOG.gz
# 1328 1329 /AGILE_PROC3/DATA_ASDCSTDk/LOG/ag-224164734_STD1Kal.LOG.gz
# files  <_io.TextIOWrapper name='MySource_list_of_orbits_224121600.0_224208000.0.txt' mode='w' encoding='UTF-8'>  created successfully
# Merging fits....
# Computing angular distance to the center of f.o.v
# This might take a while...
# Total integration time= 75574.00  s Total_bins: 0.0 75574 Mean sep. <  60 : 43.2165
# Total absolute time= 86400.00
# Total time spent at separation <  60  deg: 22480.00 s
# Relative time spent at separation < 60  deg: 29.75 %
# Relative time spent at separation > 60  deg: 70.25 %
# Absolute time spent at separation < 60  deg: 26.02  %
# Absolute time spent at separation > 60  deg: 61.45  %
# Duty Cycle:  87.47 %
# Plotting figure...
# Saving figure...
# Plotting histogram...
# Saving figure...
# Plotting figure...
# Saving figure...
# Plotting histogram...
# Saving histogram...
# 2020-10-20 16:28:34,318 [INFO    ] [AGEngVisibility2] Output directory: dir_49_60_55599.0_55600.0

# %% [markdown]
# ## Comparison tool

# %% [markdown]
# ### Data

# %%
ap_agile = "/data01/homes/addis/Agilepy/agilepy/external_packages/ap/AGILE3.ap4"
ap_fermi = "/data01/homes/addis/Agilepy/agilepy/external_packages/ap/FERMI5.ap4"
tstart = 55599.0
tstop = 55600.0
path_offaxis = dir
lines = [55599.2, 55599.4]
plotrate = False

# %% [markdown]
# ### Run tool

# %%
ageng.apOffaxisComparation(ap_agile, ap_fermi, tstart, tstop, path_offaxis, lines, plotrate)
# Out:
# Green box in:  55599.06591834183 55599.085933124086
# Green box in:  55599.13408382718 55599.15558592185
# Green box in:  55599.20377132947 55599.22490304285
# Green box in:  55599.275929936484 55599.29410443218
# Green box in:  55599.346850030786 55599.36327109665
# Green box in:  55599.417307206975 55599.43218314434
# Green box in:  55599.48738822668 55599.49729888489
# Green box in:  55599.92473197769 55599.9400419526
# Total time in GTI 14273.651556693017
# AGILE mean 0.375
# AGILE median 0.0
# AGILE std 0.7696696072652383
# Fermi mean 2.9743589743589745
# Fermi median 3.0
# Fermi std 1.92609749284838
# Total time in GTI(bottom plot) 11700.0
