# %% [markdown]
# # Offaxis Class Test

# %% [markdown]
# ## import

# %%
from create_offaxis_plot import *

# %% [markdown]
# ## Time windows

# %%
time_windows = [[54733,54734],[54735,54736]]

# %% [markdown]
# ## Class Init

# %% [markdown]
# Create_offaxis_plot(time_windows, ra, dec, path_dati_fermi, path_log_index, run_number, zmax, mode, step)

# %%
offaxis = Create_offaxis_plot([[54732.0, 54733.0], [54735.0,54738.0]], 263.85, -32.93, "/data01/FERMI_DATA/SC00.fits", "/data01/ASDC_PROC3/DATA_ASDCe/INDEX/LOG.log.index", 43, 60, "all", 1)

# %% [markdown]
# ## Run tool

# %%
dir = offaxis.run()
# Out:
# new -----
#  54732.0 54733.0
# fermi time243820800.0 243907200.0
# Computing angular distance to the center of f.o.v
# This might take a while...
# Total integration time= 72796.41  s Total_bins: 0.0 2434 Mean sep. <  60 : 42.723
# Total absolute time= 86400.00
# Total time spent at separation <  60  deg: 16570.47 s
# Relative time spent at separation < 60  deg: 22.76 %
# Relative time spent at separation > 60  deg: 77.24 %
# Absolute time spent at separation < 60  deg: 19.18  %
# Absolute time spent at separation > 60  deg: 65.08  %
# Duty Cycle:  84.26 %
# Plotting figure...
# Saving figure...
# Plotting histogram...
# Saving figure...
# agile 149212800.0 149299200.0
# 472 1e+20 /AGILE_PROC3/DATA_ASDCe/LOG/ag-149169535_STD0P_GO.LOG.gz
# 472 473 /AGILE_PROC3/DATA_ASDCe/LOG/ag-149255935_STD0P_GO.LOG.gz
# files  <_io.TextIOWrapper name='MySource_list_of_orbits_149212800.0_149299200.0.txt' mode='w' encoding='UTF-8'>  created successfully
# Merging fits....
# Computing angular distance to the center of f.o.v
# This might take a while...
# Total integration time= 72244.00  s Total_bins: 0.0 72244 Mean sep. <  60 : 7.8783
# Total absolute time= 86400.00
# Total time spent at separation <  60  deg: 72244.00 s
# Relative time spent at separation < 60  deg: 100.00 %
# Relative time spent at separation > 60  deg: 0.00 %
# Absolute time spent at separation < 60  deg: 83.62  %
# Absolute time spent at separation > 60  deg: 0.00  %
# Duty Cycle:  83.62 %
# Plotting figure...
# Saving figure...
# Plotting histogram...
# Saving figure...
# Plotting figure...
# Saving figure...
# Plotting histogram...
# Saving histogram...
# new -----
#  54735.0 54738.0
# fermi time244080000.0 244339200.0
# Computing angular distance to the center of f.o.v
# This might take a while...
# Total integration time= 217847.05  s Total_bins: 2.0 7286 Mean sep. <  60 : 41.9227
# Total absolute time= 259200.00
# Total time spent at separation <  60  deg: 50044.01 s
# Relative time spent at separation < 60  deg: 22.97 %
# Relative time spent at separation > 60  deg: 77.03 %
# Absolute time spent at separation < 60  deg: 19.31  %
# Absolute time spent at separation > 60  deg: 64.74  %
# Duty Cycle:  84.05 %
# Plotting figure...
# Saving figure...
# Plotting histogram...
# Saving figure...
# agile 149472000.0 149731200.0
# 475 1e+20 /AGILE_PROC3/DATA_ASDCe/LOG/ag-149428735_STD0P_GO.LOG.gz
# 475 1e+20 /AGILE_PROC3/DATA_ASDCe/LOG/ag-149515135_STD0P_GO.LOG.gz
# 475 1e+20 /AGILE_PROC3/DATA_ASDCe/LOG/ag-149601535_STD0P_GO.LOG.gz
# 475 478 /AGILE_PROC3/DATA_ASDCe/LOG/ag-149687935_STD0P_GO.LOG.gz
# files  <_io.TextIOWrapper name='MySource_list_of_orbits_149472000.0_149731200.0.txt' mode='w' encoding='UTF-8'>  created successfully
# Merging fits....
# Computing angular distance to the center of f.o.v
# This might take a while...
# Total integration time= 194039.99  s Total_bins: 2.0 194040 Mean sep. <  60 : 11.298
# Total absolute time= 259200.00
# Total time spent at separation <  60  deg: 194039.99 s
# Relative time spent at separation < 60  deg: 100.00 %
# Relative time spent at separation > 60  deg: 0.00 %
# Absolute time spent at separation < 60  deg: 74.86  %
# Absolute time spent at separation > 60  deg: 0.00  %
# Duty Cycle:  74.86 %
# Plotting figure...
# Saving figure...
# Plotting histogram...
# Saving figure...
# Plotting figure...
# Saving figure...
# Plotting histogram...
# Saving histogram...

# %%
print(dir)
# Out:
# dir_43_60_54735.0_54738.0
